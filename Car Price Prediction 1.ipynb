# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('scrap price.csv')
df.head()
# Out:
#    ID  symboling                      name fueltypes aspiration doornumbers  \
# 0   1          3        alfa-romero giulia       gas        std         two
# 1   2          3       alfa-romero stelvio       gas        std         two
# 2   3          1  alfa-romero Quadrifoglio       gas        std         two
# 3   4          2               audi 100 ls       gas        std        four
# 4   5          2                audi 100ls       gas        std        four
#
#        carbody drivewheels enginelocation  wheelbase  ...  enginesize  \
# 0  convertible         rwd          front       88.6  ...         130
# 1  convertible         rwd          front       88.6  ...         130
# 2    hatchback         rwd          front       94.5  ...         152
# 3        sedan         fwd          front       99.8  ...         109
# 4        sedan         4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   name              205 non-null    object
#  3   fueltypes         205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumbers       205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheels       205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.isna().sum()
# Out:
# ID                  0
# symboling           0
# name                0
# fueltypes           0
# aspiration          0
# doornumbers         0
# carbody             0
# drivewheels         0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.describe().T
# Out:
#                   count          mean          std      min      25%  \
# ID                205.0    103.000000    59.322565     1.00    52.00
# symboling         205.0      0.834146     1.245307    -2.00     0.00
# wheelbase         205.0     98.756585     6.021776    86.60    94.50
# carlength         205.0    174.049268    12.337289   141.10   166.30
# carwidth          205.0     65.907805     2.145204    60.30    64.10
# carheight         205.0     53.724878     2.443522    47.80    52.00
# curbweight        205.0   2555.565854   520.680204  1488.00  2145.00
# enginesize        205.0    126.907317    41.642693    61.00    97.00
# boreratio         205.0      3.329756     0.270844     2.54     3.15
# stroke            205.0      3.255415     0.313597     2.07     3.11
# compressionratio  205.0     10.142537     3.972040     7.00     8.60
# horsepower        205.0    104.117073    39.544167    48.00    70.00
# peakrpm           205.0   5125.121951   476.985643  4150.00  4800.00
# ...

# %% [markdown]
# # Seaborn Visualization

# %%
df.head(2)
# Out:
#    ID  symboling                 name fueltypes aspiration doornumbers  \
# 0   1          3   alfa-romero giulia       gas        std         two
# 1   2          3  alfa-romero stelvio       gas        std         two
#
#        carbody drivewheels enginelocation  wheelbase  ...  enginesize  \
# 0  convertible         rwd          front       88.6  ...         130
# 1  convertible         rwd          front       88.6  ...         130
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
#
# [2 rows x 26 columns]

# %%
#lineplot
plt.figure(figsize = (14,10))
plt.title('Car Price Prediction')
sns.lineplot(data = df)
# Out:
# <Axes: title={'center': 'Car Price Prediction'}>

# %%
#barplot
plt.figure(figsize = (10,6))
plt.title('Car Price Prediction')
sns.barplot(x = df.index, y = df['enginesize'])
# Out:
# <Axes: title={'center': 'Car Price Prediction'}, ylabel='enginesize'>

# %%
#heatmap
'''plt.figure(figsize = (10,6))
plt.title('Car Price Prediction')
sns.heatmap(data = df, annot = True)'''
# Out:
# "plt.figure(figsize = (10,6))\nplt.title('Car Price Prediction')\nsns.heatmap(data = df, annot = True)"

# %%
#scatter plots
sns.regplot(x = df['stroke'], y = df['price'])
# Out:
# <Axes: xlabel='stroke', ylabel='price'>

# %%
sns.lmplot(x ='stroke', y ='price', hue = 'carbody', data = df)

# %%
#density kde plot
sns.kdeplot(data = df['price'], shade = True)
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
#color-coded plots
sns.histplot(data = df, x = 'price', hue = 'stroke')
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %% [markdown]
# # Data Preprocessing

# %%
df = df.drop('ID', axis = 1)
df
# Out:
#      symboling                      name fueltypes aspiration doornumbers  \
# 0            3        alfa-romero giulia       gas        std         two
# 1            3       alfa-romero stelvio       gas        std         two
# 2            1  alfa-romero Quadrifoglio       gas        std         two
# 3            2               audi 100 ls       gas        std        four
# 4            2                audi 100ls       gas        std        four
# ..         ...                       ...       ...        ...         ...
# 200         -1           volvo 145e (sw)       gas        std        four
# 201         -1               volvo 144ea       gas      turbo        four
# 202         -1               volvo 244dl       gas        std        four
# 203         -1                 volvo 246    diesel      turbo        four
# 204         -1               volvo 264gl       gas      turbo        four
#
#          carbody drivewheels enginelocation  wheelbase  carlength  ...  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for column in df.columns:
    if df[column].dtype == np.number:
        continue
    df[column] = LabelEncoder().fit_transform(df[column])

# %%
df
# Out:
#      symboling  name  fueltypes  aspiration  doornumbers  carbody  \
# 0            5     2          1           0            1        0
# 1            5     3          1           0            1        0
# 2            3     1          1           0            1        2
# 3            4     4          1           0            0        3
# 4            4     5          1           0            0        3
# ..         ...   ...        ...         ...          ...      ...
# 200          1   139          1           0            0        3
# 201          1   138          1           1            0        3
# 202          1   140          1           0            0        3
# 203          1   142          0           1            0        3
# 204          1   143          1           1            0        3
#
#      drivewheels  enginelocation  wheelbase  carlength  ...  enginesize  \
# 0              2               0       88.6      168.8  ...          18
# ...

# %%
x = df.drop('price',axis = 1)

# %%
y = df['price']

# %%
x.head()
# Out:
#    symboling  name  fueltypes  aspiration  doornumbers  carbody  drivewheels  \
# 0          5     2          1           0            1        0            2
# 1          5     3          1           0            1        0            2
# 2          3     1          1           0            1        2            2
# 3          4     4          1           0            0        3            1
# 4          4     5          1           0            0        3            0
#
#    enginelocation  wheelbase  carlength  ...  cylindernumber  enginesize  \
# 0               0       88.6      168.8  ...               2          18
# 1               0       88.6      168.8  ...               2          18
# 2               0       94.5      171.2  ...               3          28
# 3               0       99.8      176.6  ...               2          11
# 4               0       99.4      176.6  ...               1          22
#
# ...

# %%
y.head()
# Out:
# 0    13495.0
# 1    16500.0
# 2    16500.0
# 3    13950.0
# 4    17450.0
# Name: price, dtype: float64

# %% [markdown]
# # Train-Test-Split

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y, test_size = .30 ,random_state = 42)

# %%
xtrain.head()
# Out:
#      symboling  name  fueltypes  aspiration  doornumbers  carbody  \
# 177          1   125          1           0            0        2
# 75           3    62          1           1            1        2
# 174          1   113          0           1            0        3
# 31           4    43          1           0            1        2
# 12           2    11          1           0            1        3
#
#      drivewheels  enginelocation  wheelbase  carlength  ...  cylindernumber  \
# 177            1               0      102.4      175.6  ...               2
# 75             2               0      102.7      178.4  ...               2
# 174            1               0      102.4      175.6  ...               2
# 31             1               0       86.6      144.6  ...               2
# 12             2               0      101.2      176.8  ...               3
#
#      enginesize  fuelsystem  boreratio  stroke  compressionratio  horsepower  \
# ...

# %%
ytest.head(2)
# Out:
# 15    30760.000
# 9     17859.167
# Name: price, dtype: float64

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
li = LinearRegression()

# %%
li.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
li.score(xtest,ytest)
# Out:
# 0.7830897078432715

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
pred = li.predict(xtest)

# %%
mean_squared_error(ytest,pred)
# Out:
# 15028494.806469569

# %%
r2_score(ytest,pred)
# Out:
# 0.7830897078432715
